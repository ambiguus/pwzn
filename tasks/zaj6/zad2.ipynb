# %%
import pandas as pd

# %matplotlib inline

# %% [markdown]
# # Wprowadzenie

# %% [markdown]
# Dane są zasadniczo te same co ostatnim razem, ale pochodzą z innego źródła. Mają też trochę inny format.
#
# Zasadnicze zadanie polega na zebraniu całych danych z pliku XLS (oba arkusze!), a następnie sformatowaniu ich do jednolitej postaci. Następnie należy te wyniki połączyć z wynikami z poprzedniego zadania.
#
# Dane są w pliku: "data-cl.xls".
#
# Załaduj dane do ramki pandas z jednego arkusza:

# %%
dane1 = pd.read_excel('data-cl.xls', 'Sheet1', index_col=None, na_values=['NA'])
dane2 = pd.read_excel('data-cl.xls', 'Sheet2', index_col=None, na_values=['NA'])

# %% [markdown]
# Jak zauważyłeś/aś dane dane mają dziwną strukturę, W wierszach mamy pomiar w kolejnych tygodniach dla poszczególnych stacji i lat.
#
# Na razie celem jest przekształcenie tych danyh na tabelkę o strukturze zawierającej kolumny: Data, Rodzaj Radionuklidu, Stacja, Wartość.
#
# Kolejność przekształceń jest taka (może wpadniecie na lepszą):
#
# * Na początek porządek w danych. Należy usunąć puste rzędy na górze, wyrzucić kolumnę w której jest tylko 7Be, nadać kolumnie z rokiem nazwę Rok, oraz kolumnie ze stacją nazwę Stacja.
# * Za pomocą funkcji pd.melt(...) dokonać unpivotowania danych
# * Z Roku i tygodnia wyznaczyć datę (jak w ostatnim ćwiczeniu).

# %%
from datetime import date, timedelta
def week_start_date(year, week, dow=0):    
    """
    :param int year: Numer roku
    :param int week: Numer tygodnia w roku 
    :param int dow: Funkcja ta zwraca datę, zwróci datę dnia o indeksie dow, zero oznacza poniedziałek, jeden wtorek itp. 
    """
    # http://stackoverflow.com/a/1287862/7918
    d = date(year, 1, 1)    
    delta_days = d.isoweekday() - 1
    delta_weeks = week
    if year == d.isocalendar()[0]:
        delta_weeks -= 1
    delta = timedelta(days=-delta_days+dow, weeks=delta_weeks)
    return d + delta

# %%
dane1 = dane1[1:]
dane1
# Out:
#    Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 1         NaN        2008   Stacja A         NaN         NaN         NaN
# 2         NaN         NaN   Stacja B         NaN         NaN         NaN
# 3         NaN         NaN   Stacja C         NaN         NaN         NaN
# 4         NaN        2009   Stacja A         NaN         NaN         NaN
# 5         NaN         NaN   Stacja B         NaN         NaN         NaN
# 6         NaN         NaN   Stacja C         NaN         NaN         NaN
# 7         NaN         NaN   Stacja D         NaN         NaN         NaN
# 8         NaN        2010   Stacja A         259         428         369
# 9         NaN         NaN   Stacja B         174         280         175
# 10        NaN         NaN   Stacja C         281         389         384
# 11        NaN         NaN   Stacja D         232         206         226
# 12        NaN         NaN   Stacja E         NaN         NaN         NaN
# 13        NaN        2011   Stacja A         242         165         407
# 14        NaN         NaN   Stacja B         293         NaN         264
# 15        NaN         NaN   Stacja C         397         NaN         256
# 16        NaN         NaN   Stacja D         288         NaN         165
# 17        NaN         NaN   Stacja E         386         NaN         292
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9     ...       Unnamed: 45  \
# 1          NaN         NaN         NaN         NaN     ...               423
# 2          NaN         NaN         NaN         NaN     ...               577
# 3          NaN         NaN         NaN         NaN     ...               243
# 4          NaN         NaN         NaN         NaN     ...               504
# 5          NaN         NaN         NaN         NaN     ...               346
# 6          NaN         NaN         NaN         NaN     ...               260
# 7          NaN         NaN         NaN         NaN     ...               NaN
# 8          184         288         299         336     ...               437
# 9          231         323         351         446     ...               291
# 10         348         245         419         399     ...               382
# 11         198         268         227         371     ...               209
# 12         NaN         NaN         NaN         NaN     ...               391
# 13         394         163         326         325     ...               217
# 14         268         193         416         452     ...               190
# 15         295         386         244         292     ...               302
# 16         203         364         321         540     ...               197
# 17         285         395         511         502     ...               124
#
#     Unnamed: 46  Unnamed: 47  Unnamed: 48  Unnamed: 49  Unnamed: 50  \
# 1           233          280          260          221          199
# 2           414          251          281          270          479
# 3           473          456          435          289          446
# 4           489          314          NaN          NaN          NaN
# 5           419          402          322          258          366
# 6           221          447          193          224          201
# 7           266          352          292          278          115
# 8           436          385          433          486          216
# 9           324          325          368          393          244
# 10          548          281          308          403          329
# 11          NaN          191          501          428          187
# 12          556          276          358          493          153
# 13          397          212          273          337          NaN
# 14          556          124          217          234          321
# 15          396          421          362          183          383
# 16          594          519          223          350          403
# 17          359          346          190          459          239
#
#     Unnamed: 51  Unnamed: 52  Unnamed: 53  Unnamed: 54
# 1           245          229          171          225
# 2           242          126          169          345
# 3           226          190          369          185
# 4           NaN          NaN          NaN          NaN
# 5           158          244          256          298
# 6           399          294          196          192
# 7           335          163          164          327
# 8           169          342          197          133
# 9           349          191          243          185
# 10          407          248          376          370
# 11          268          225          141          145
# 12          188          240          204          253
# 13          NaN          NaN          NaN          185
# 14          237          360          391          117
# 15          353          418          253          399
# 16          393          375          375          317
# 17          381          309          244          352
#
# [17 rows x 55 columns]

# %% [markdown]
# ### Pobranie danych z drugiego skoroszytu

# %% [markdown]
# Tak samo pobierz dane z drugiego skoroszytu (zawiera on inny radionuklid)

# %% [markdown]
# ### Doklejenie wyników

# %% [markdown]
# Pobierz wyniki z zadania 1 i sformatuj je do takiej samej postaci (powiedzmy że pochodzą one ze stacji o nazwie: "Stacja Hor"), następnie połącz ramki razem

# %% [markdown]
# ### Pivoting pełnych danych

# %% [markdown]
# Teraz skonstruuj tabelkę zawierającą takie kolumny:
#
# * Data
# * Dla każdej kombinacji Stacji i parametru kolumnę z poziomem zanieczyszczenia

# %% [markdown]
# ### Wyniki

# %% [markdown]
# Wyświetl wyniki w ładnym wykresie :)
