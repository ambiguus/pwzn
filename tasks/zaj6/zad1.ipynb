# %% [markdown]
# # Wyjaśnienie

# %% [markdown]
# Dostajecie teraz dane, bardzo podobne do takich na których pracuje się w  "prawdziwej nauce" (w takiej formie dostałem kiedyś prawdziwe dane pomiarowe).
#
# Dane dotyczą poziomów radionuklidów w powietrzu przy gruntowym, są to dość trudne pomiary do przeprowadzenia, ponieważ rejestruje się bardzo niskie dawki (aktywności w powietrzu są rzędu mikrobekereli). Procedura pomiarowa wygląda (z grubsza) tak:
#
# * Przepuszczamy powierze pompowane przez wysokowydajną pompę, przez płachtę filtru przez tydzień.
# * Prasujemy filtr
# * Zbieramy spektrum gamma
# * Po kilku obliczeniach (uwzględniających okres półtrwania niektórych nuklidów) otrzymujemy aktywność.
#
#
# Dane które otrzymaliście są wygenerowane :)

# %% [markdown]
# Dane są w pliku: "data.csv" w tym katalogu.

# %% [markdown]
# # Zadanie 1

# %% [markdown]
# Teraz zaimportuj pandas, oraz zainicjalizuj matplotlib:

# %%
# %matplotlib inline
import matplotlib as mpl
import pandas as pd

# %% [markdown]
# Załaduj plik z danymi (dobrym pomysłem jest obejrzenie go w arkuszu kalkulacyjnym)

# %%
# %%bash
# ls
# Out:
# data-cl-generate.ods
# data-cl-generate.pdf.ods
# data-cl.xls
# data.csv
# data-errors.csv
# data-errors.ods
# data-generate.
# data-generate.ods
# zad1.ipynb
# zad2.ipynb
# zad3.ipynb

# %%
data = pd.read_csv('data.csv', header=1)

# %%
data = data[:].fillna(0)
#print(data)

# %%
print(data)
# Out:
#       Rok  Tyg  Dust   7Be  137Cs  210Pb   40K  22Na  134Cs
# 0    2010    1     0     0  0.000    0.0  0.00  0.00      0
# 1    2010    2     0     0  0.000    0.0  0.00  0.00      0
# 2    2010    3     0     0  0.000    0.0  0.00  0.00      0
# 3    2010    4     0     0  0.000    0.0  0.00  0.00      0
# 4    2010    5     0     0  0.000    0.0  0.00  0.00      0
# 5    2010    6     0     0  0.000    0.0  0.00  0.00      0
# 6    2010    7     0     0  0.000    0.0  0.00  0.00      0
# 7    2010    8     0     0  0.000    0.0  0.00  0.00      0
# 8    2010    9     0     0  0.000    0.0  0.00  0.00      0
# 9    2010   10     0     0  0.000    0.0  0.00  0.00      0
# 10   2010   11     0     0  0.000    0.0  0.00  0.00      0
# 11   2010   12     0     0  0.000    0.0  0.00  0.00      0
# 12   2010   13     0     0  0.000    0.0  0.00  0.00      0
# 13   2010   14     0     0  0.000    0.0  0.00  0.00      0
# 14   2010   15     0     0  0.000    0.0  0.00  0.00      0
# 15   2010   16     0     0  0.000    0.0  0.00  0.00      0
# 16   2010   17     0     0  0.000    0.0  0.00  0.00      0
# 17   2010   18     0     0  0.000    0.0  0.00  0.00      0
# 18   2010   19     0     0  0.000    0.0  0.00  0.00      0
# 19   2010   20     0     0  0.000    0.0  0.00  0.00      0
# 20   2010   21     0     0  0.000    0.0  0.00  0.00      0
# 21   2010   22     0     0  0.000    0.0  0.00  0.00      0
# 22   2010   23     0     0  0.000    0.0  0.00  0.00      0
# 23   2010   24     0     0  0.000    0.0  0.00  0.00      0
# 24   2010   25     0     0  0.000    0.0  0.00  0.00      0
# 25   2010   26     0     0  0.000    0.0  0.00  0.00      0
# 26   2010   27     0     0  0.000    0.0  0.00  0.00      0
# 27   2010   28     0     0  0.000    0.0  0.00  0.00      0
# 28   2010   29     0     0  0.000    0.0  0.00  0.00      0
# 29   2010   30     0     0  0.000    0.0  0.00  0.00      0
# ..    ...  ...   ...   ...    ...    ...   ...   ...    ...
# 230  2014   23     6   488  0.713   52.5  2.34  4.84      0
# 231  2014   24    16  1584  0.429  106.5  8.52  3.73      0
# 232  2014   25    39  1430  0.729   76.7  6.73  9.24      0
# 233  2014   26    43  1082  0.685   67.3  7.71  9.82      0
# 234  2014   27    32   486  0.348   49.4  6.77  4.12      0
# 235  2014   28    11  1444  0.401   52.1  6.40  6.00      0
# 236  2014   29     0     0  0.000    0.0  0.00  0.00      0
# 237  2014   30     0     0  0.000    0.0  0.00  0.00      0
# 238  2014   31     0     0  0.000    0.0  0.00  0.00      0
# 239  2014   32     0     0  0.000    0.0  0.00  0.00      0
# 240  2014   33     0     0  0.000    0.0  0.00  0.00      0
# 241  2014   34     0     0  0.000    0.0  0.00  0.00      0
# 242  2014   35     0     0  0.000    0.0  0.00  0.00      0
# 243  2014   36     0     0  0.000    0.0  0.00  0.00      0
# 244  2014   37     0     0  0.000    0.0  0.00  0.00      0
# 245  2014   38     0     0  0.000    0.0  0.00  0.00      0
# 246  2014   39     0     0  0.000    0.0  0.00  0.00      0
# 247  2014   40     0     0  0.000    0.0  0.00  0.00      0
# 248  2014   41     0     0  0.000    0.0  0.00  0.00      0
# 249  2014   42     0     0  0.000    0.0  0.00  0.00      0
# 250  2014   43     0     0  0.000    0.0  0.00  0.00      0
# 251  2014   44     0     0  0.000    0.0  0.00  0.00      0
# 252  2014   45     0     0  0.000    0.0  0.00  0.00      0
# 253  2014   46     0     0  0.000    0.0  0.00  0.00      0
# 254  2014   47     0     0  0.000    0.0  0.00  0.00      0
# 255  2014   48     0     0  0.000    0.0  0.00  0.00      0
# 256  2014   49     0     0  0.000    0.0  0.00  0.00      0
# 257  2014   50     0     0  0.000    0.0  0.00  0.00      0
# 258  2014   51     0     0  0.000    0.0  0.00  0.00      0
# 259  2014   52     0     0  0.000    0.0  0.00  0.00      0
#
# [260 rows x 9 columns]

# %% [markdown]
# ### Określenie dat

# %% [markdown]
# W pliku pomiary nie mają dat, ale rok i tydzień dokonania pomiaru (w pomiarach radionuklidów w powietrzu przez tydzień zbiera się radionuklidy na filtrze).
#
# Zauważcie że w pliku w wierszu z rokiem nie ma wartości w każdym wierszu. Uzupełnij brakujące dane.

# %% [markdown]
# Teraz przekonwertuj zawartość kolumny Rok do liczb stałoprzeninkowych. To samo zrób z kolumną Tyg

# %%
data['Rok']=data['Rok'].astype(int)
data['Tyg'] = data['Tyg'].astype(int)

# %% [markdown]
# Dodaj do ramki pole Data, które będzie zawierać datę pomiaru. Datę pomiaru wyznaczasz z roku i numeru tygodnia (wg. kalendzarza ISO). Przeliczenie roku i tygodnia na datę pomiaru wykonaj za pomocą dostarczonej funkcji.
#
# **Uwaga** tego nie da się zwektoryzować, proszę po prostu przeiterować po poszczególnych wierszach wybranych kolumn.

# %%
import numpy as np

# %%
from datetime import date, timedelta
def week_start_date(year, week, dow=0):    
    """
    :param int year: Numer roku
    :param int week: Numer tygodnia w roku 
    :param int dow: Funkcja ta zwraca datę, zwróci datę dnia o indeksie dow, zero oznacza poniedziałek, jeden wtorek itp. 
    """
    # http://stackoverflow.com/a/1287862/7918
    d = date(year, 1, 1)    
    delta_days = d.isoweekday() - 1
    delta_weeks = week
    if year == d.isocalendar()[0]:
        delta_weeks -= 1
    delta = timedelta(days=-delta_days+dow, weeks=delta_weeks)
    return d + delta

# %%
column_data = np.zeros((data.Rok.shape[0], 1),dtype=object)
for index, row in data.iterrows():
    column_data[index] = week_start_date(year=int(row.loc['Rok']), week=int(row.loc['Tyg']))
data['Data'] = column_data

# %% [markdown]
# Ustaw kolumnę "Date" tak by była indeksem Twojej ramki.

# %%
data.set_index("Data", inplace=True)

# %% [markdown]
# Wyświetl poziomy pyłu (kolumna dust) oraz Berylu (7Be)

# %%
data.Dust.plot()

# %%
data["7Be"].plot()

# %% [markdown]
# ### Średnie miesięczne

# %% [markdown]
# Wyznacz średnie miesięczne poziomów zanieczyszczeń. W tym celu musisz:
#
# *Rozwiązanie nieładne*
#
# 1. Dodać do ramki kolumnę month, która wskasuje miesiąc danego pomiaru.
# 2. Odpalić group_by na miesiącu
# 3. Policzyć średnią
#
# *Rozwiązanie ładne*
#
# 1. Ustawić kolumnę Date jako indeks ramki (musi być typu pd.DatetimeIndex),
#    patrz: http://stackoverflow.com/q/17328655/7918
# 2. użyć df.resample

# %%
data = data.set_index(pd.DatetimeIndex(data.index))
data
# Out:
#              Rok  Tyg  Dust   7Be  137Cs  210Pb   40K  22Na  134Cs
# 2010-01-04  2010    1     0     0  0.000    0.0  0.00  0.00      0
# 2010-01-11  2010    2     0     0  0.000    0.0  0.00  0.00      0
# 2010-01-18  2010    3     0     0  0.000    0.0  0.00  0.00      0
# 2010-01-25  2010    4     0     0  0.000    0.0  0.00  0.00      0
# 2010-02-01  2010    5     0     0  0.000    0.0  0.00  0.00      0
# 2010-02-08  2010    6     0     0  0.000    0.0  0.00  0.00      0
# 2010-02-15  2010    7     0     0  0.000    0.0  0.00  0.00      0
# 2010-02-22  2010    8     0     0  0.000    0.0  0.00  0.00      0
# 2010-03-01  2010    9     0     0  0.000    0.0  0.00  0.00      0
# 2010-03-08  2010   10     0     0  0.000    0.0  0.00  0.00      0
# 2010-03-15  2010   11     0     0  0.000    0.0  0.00  0.00      0
# 2010-03-22  2010   12     0     0  0.000    0.0  0.00  0.00      0
# 2010-03-29  2010   13     0     0  0.000    0.0  0.00  0.00      0
# 2010-04-05  2010   14     0     0  0.000    0.0  0.00  0.00      0
# 2010-04-12  2010   15     0     0  0.000    0.0  0.00  0.00      0
# 2010-04-19  2010   16     0     0  0.000    0.0  0.00  0.00      0
# 2010-04-26  2010   17     0     0  0.000    0.0  0.00  0.00      0
# 2010-05-03  2010   18     0     0  0.000    0.0  0.00  0.00      0
# 2010-05-10  2010   19     0     0  0.000    0.0  0.00  0.00      0
# 2010-05-17  2010   20     0     0  0.000    0.0  0.00  0.00      0
# 2010-05-24  2010   21     0     0  0.000    0.0  0.00  0.00      0
# 2010-05-31  2010   22     0     0  0.000    0.0  0.00  0.00      0
# 2010-06-07  2010   23     0     0  0.000    0.0  0.00  0.00      0
# 2010-06-14  2010   24     0     0  0.000    0.0  0.00  0.00      0
# 2010-06-21  2010   25     0     0  0.000    0.0  0.00  0.00      0
# 2010-06-28  2010   26     0     0  0.000    0.0  0.00  0.00      0
# 2010-07-05  2010   27     0     0  0.000    0.0  0.00  0.00      0
# 2010-07-12  2010   28     0     0  0.000    0.0  0.00  0.00      0
# 2010-07-19  2010   29     0     0  0.000    0.0  0.00  0.00      0
# 2010-07-26  2010   30     0     0  0.000    0.0  0.00  0.00      0
# ...          ...  ...   ...   ...    ...    ...   ...   ...    ...
# 2014-06-02  2014   23     6   488  0.713   52.5  2.34  4.84      0
# 2014-06-09  2014   24    16  1584  0.429  106.5  8.52  3.73      0
# 2014-06-16  2014   25    39  1430  0.729   76.7  6.73  9.24      0
# 2014-06-23  2014   26    43  1082  0.685   67.3  7.71  9.82      0
# 2014-06-30  2014   27    32   486  0.348   49.4  6.77  4.12      0
# 2014-07-07  2014   28    11  1444  0.401   52.1  6.40  6.00      0
# 2014-07-14  2014   29     0     0  0.000    0.0  0.00  0.00      0
# 2014-07-21  2014   30     0     0  0.000    0.0  0.00  0.00      0
# 2014-07-28  2014   31     0     0  0.000    0.0  0.00  0.00      0
# 2014-08-04  2014   32     0     0  0.000    0.0  0.00  0.00      0
# 2014-08-11  2014   33     0     0  0.000    0.0  0.00  0.00      0
# 2014-08-18  2014   34     0     0  0.000    0.0  0.00  0.00      0
# 2014-08-25  2014   35     0     0  0.000    0.0  0.00  0.00      0
# 2014-09-01  2014   36     0     0  0.000    0.0  0.00  0.00      0
# 2014-09-08  2014   37     0     0  0.000    0.0  0.00  0.00      0
# 2014-09-15  2014   38     0     0  0.000    0.0  0.00  0.00      0
# 2014-09-22  2014   39     0     0  0.000    0.0  0.00  0.00      0
# 2014-09-29  2014   40     0     0  0.000    0.0  0.00  0.00      0
# 2014-10-06  2014   41     0     0  0.000    0.0  0.00  0.00      0
# 2014-10-13  2014   42     0     0  0.000    0.0  0.00  0.00      0
# 2014-10-20  2014   43     0     0  0.000    0.0  0.00  0.00      0
# 2014-10-27  2014   44     0     0  0.000    0.0  0.00  0.00      0
# 2014-11-03  2014   45     0     0  0.000    0.0  0.00  0.00      0
# 2014-11-10  2014   46     0     0  0.000    0.0  0.00  0.00      0
# 2014-11-17  2014   47     0     0  0.000    0.0  0.00  0.00      0
# 2014-11-24  2014   48     0     0  0.000    0.0  0.00  0.00      0
# 2014-12-01  2014   49     0     0  0.000    0.0  0.00  0.00      0
# 2014-12-08  2014   50     0     0  0.000    0.0  0.00  0.00      0
# 2014-12-15  2014   51     0     0  0.000    0.0  0.00  0.00      0
# 2014-12-22  2014   52     0     0  0.000    0.0  0.00  0.00      0
#
# [260 rows x 9 columns]

# %% [markdown]
# ### Zapis wyników

# %% [markdown]
# Zapisz wyniki tygodniowe do jakiegoś formatu:

# %%
data.to_cs
